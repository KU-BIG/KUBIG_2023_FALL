# %%
# Problem 1

values = range(10, 21)


# 1-1 Print 10~15 with list and iterating over iterables

# 1-2 Get the sum of values

# 1-3 Print same indexes and values with enumerate and for loop
# ex) 10 10, 11 11, 22 22 ...

# %%
# Problem 2

# 2-1 Make simple multiplication table program with for loop and input()

step = input('숫자 입력 : ')



# 2-2 Print the people who got the score over 60

import random

names = ['Charlie', 'Ed', 'Margo', 'Tom', 'Kim', 'Lee', 'Alex']
people_scores = {people:random.randint(1,100) for people in names}



# 2-3 Get the number of letters as a dictionary form about each of the words in a sentence.

sentence = "My favorite food is hamburgers without cucumber"
